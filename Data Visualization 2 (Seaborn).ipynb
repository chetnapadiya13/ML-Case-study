# %% [markdown]
# # Visualization 2 (seaborn)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
'''
seaborn provides better plots as compared to matplotlib aslo provide some automated calculation 
so seaborn used by all ML and Data processing Engineers 
'''
# Out:
# '\nseaborn provides better plots as compared to matplotlib aslo provide some automated calculation \nso seaborn used by all ML and Data processing Engineers \n'

# %%
df=pd.read_csv("data/Automobile_data.csv")

# %%
df
# Out:
#      symboling normalized-losses         make fuel-type   body-style  \
# 0            3                 ?  alfa-romero       gas  convertible
# 1            3                 ?  alfa-romero       gas  convertible
# 2            1                 ?  alfa-romero       gas    hatchback
# 3            2               164         audi       gas        sedan
# 4            2               164         audi       gas        sedan
# ..         ...               ...          ...       ...          ...
# 200         -1                95        volvo       gas        sedan
# 201         -1                95        volvo       gas        sedan
# 202         -1                95        volvo       gas        sedan
# 203         -1                95        volvo    diesel        sedan
# 204         -1                95        volvo       gas        sedan
#
#     drive-wheels engine-location  width  height engine-type  engine-size  \
# ...

# %% [markdown]
# # 1) Line Plot

# %%
x=np.arange(10)
y=np.sqrt(x)

# %%
plt.figure(figsize=(6,6))
sns.lineplot(x,y)
plt.show()

# %% [markdown]
# # 2) Histogram (Distplot)

# %%
plt.figure(figsize=(6,6))
sns.distplot(df["price"])
plt.show()

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'body-style',
#        'drive-wheels', 'engine-location', 'width', 'height', 'engine-type',
#        'engine-size', 'horsepower', 'city-mpg', 'highway-mpg', 'price'],
#       dtype='object')

# %%
plt.figure(figsize=(6,6))
sns.distplot(df["width"])
plt.show()

# %%
width_mean=df["width"].mean()
width_median=df["width"].median()

# %%
plt.figure(figsize=(6,6))
sns.distplot(df["width"])
plt.axvline(width_mean,color='red')
plt.axvline(width_median,color='yellow')
plt.show()

# %% [markdown]
# # 3) Count Plot (Bar plot)

# %%
plt.figure(figsize=(6,6))
sns.countplot(data=df,x="body-style")
#uplt.show()

# %%
# how to seperate all categorical column in one data frame 
# once we done seperation we wants to use loop to represnt countplot of each 
plt.figure(figsize=(6,6))
sns.countplot(data=df,x="make")
plt.show()

# %%
plt.figure(figsize=(6,6))
sns.countplot(data=df,y="make")
plt.show()

# %%
'''in matplotlib we have legend here we have hue '''
plt.figure(figsize=(6,6))
sns.countplot(data=df,x="body-style",hue="fuel-type")
plt.show()

# %% [markdown]
# # 4) Heatmap

# %%
'''helps us to check correlation between features it best way to see correlation of 
features when we have more than 100 features '''
# Out:
# 'helps us to check correlation between features it best way to see correlation of \nfeatures when we have more than 100 features '

# %%
corr=df.corr()

plt.figure(figsize=(7,7))
sns.heatmap(corr,annot=True)
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.heatmap(corr,annot=True,cmap="viridis")
plt.show()

# %% [markdown]
# # 5) scatter plot

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=df,x="width",y="price")
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=df,x="width",y="price",hue="body-style")
plt.show()

# %%
plt.figure(figsize=(7,7))
sns.scatterplot(data=df,x="width",y="price",hue="make")
plt.show()

# %% [markdown]
# # 6) Box Plots

# %%
plt.figure(figsize=(10,4))
sns.boxplot(data=df,x="price")
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.boxplot(data=df, x="price",y="make")
plt.show()
